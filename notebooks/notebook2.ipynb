# %%
import pandas as pd
import pickle
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# %%
df = pd.read_csv('/home/ubuntu/book_data.csv.gzip', compression='gzip')
df.head()
# Out:
#    book_id                                    title language  \
# 0  2767052  The Hunger Games (The Hunger Games, #1)      eng
# 1  2767052  The Hunger Games (The Hunger Games, #1)      eng
# 2  2767052  The Hunger Games (The Hunger Games, #1)      eng
# 3  2767052  The Hunger Games (The Hunger Games, #1)      eng
# 4  2767052  The Hunger Games (The Hunger Games, #1)      eng
#
#                                          description  reviews_count  \
# 0  Winning will make you famous.\nLosing means ce...         142645
# 1  Winning will make you famous.\nLosing means ce...         142645
# 2  Winning will make you famous.\nLosing means ce...         142645
# 3  Winning will make you famous.\nLosing means ce...         142645
# 4  Winning will make you famous.\nLosing means ce...         142645
#
#    avg_rating  ratings_count  author_id  \
# 0        4.34        4899965     153394
# 1        4.34        4899965     153394
# 2        4.34        4899965     153394
# 3        4.34        4899965     153394
# 4        4.34        4899965     153394
#
#                                            image_url             name  \
# 0  https://images.gr-assets.com/books/1447303603m...  Suzanne Collins
# 1  https://images.gr-assets.com/books/1447303603m...  Suzanne Collins
# 2  https://images.gr-assets.com/books/1447303603m...  Suzanne Collins
# 3  https://images.gr-assets.com/books/1447303603m...  Suzanne Collins
# 4  https://images.gr-assets.com/books/1447303603m...  Suzanne Collins
#
#                             user_id  rating
# 0  8842281e1d1347389f2ab93d60773d4d       5
# 1  704eb93a316aff687a93d5215882eb21       5
# 2  4b3636a043e5c99fa27ac897ccfa1151       5
# 3  012aa353140af13109d00ca36cdc0637       5
# 4  2f6af21d14c83a5df6cdcef5e6af0b3e       4

# %%
reduced_df = df.query('ratings_count > 5000')

# %%
reduced_df.shape
# Out:
# (5760801, 12)

# %%
# Remove paraentheses from book titles
reduced_df['title'] = reduced_df['title'].str.replace(r' \(.*\)','',  regex=True)
# Out:
# /tmp/ipykernel_30701/2451983157.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reduced_df['title'] = reduced_df['title'].str.replace(r' \(.*\)','',  regex=True)

# %% [markdown]
# # Setting up Recommedation System

# %%
# Let's look at the counts for each unique user_id
reduced_df['user_id'].value_counts().to_frame()
# Out:
#                                   count
# user_id
# a2d6dd1685e5aa0a72c9410f8f55e056   1840
# 8e7e5b546a63cb9add8431ee6914cf59   1770
# aca760854b57ce2ec981df32e46dc96c   1443
# ba7f50286295186a87feaeb42af2ebc1   1367
# 7b82d02a42678fbdaaee5e119981bdb8   1321
# ...                                 ...
# 24db2dd104900fcec90930d9bb045efc      1
# 5a426a2b69e96f9294b817a414f23dd8      1
# d874082dca6989cfd2e1ad5a968da81e      1
# b76573e5ae7b18be71ea13c0830902ef      1
# ae031a205bd7687bf7515d2729625205      1
#
# [370604 rows x 1 columns]

# %%
# Get list of user for users who have reviewed more than 50 books
user_ids = list(reduced_df['user_id'].value_counts().to_frame().query('count > 150').index)

# %%
# How many users do we have
len(user_ids)
# Out:
# 5372

# %%
# Subset data 
reduced_user_df = reduced_df[reduced_df['user_id'].isin(user_ids)].reset_index(drop=True)
reduced_user_df.shape
# Out:
# (1347175, 12)

# %%
reduced_user_df.columns
# Out:
# Index(['book_id', 'title', 'language', 'description', 'reviews_count',
#        'avg_rating', 'ratings_count', 'author_id', 'image_url', 'name',
#        'user_id', 'rating'],
#       dtype='object')

# %%
df_ready = reduced_user_df[['book_id','title','name','rating','user_id','image_url']]
df_ready.head()
# Out:
#    book_id             title             name  rating  \
# 0  2767052  The Hunger Games  Suzanne Collins       4
# 1  2767052  The Hunger Games  Suzanne Collins       5
# 2  2767052  The Hunger Games  Suzanne Collins       4
# 3  2767052  The Hunger Games  Suzanne Collins       3
# 4  2767052  The Hunger Games  Suzanne Collins       3
#
#                             user_id  \
# 0  fc0a0792fd1c30427acdbfecbf5b0a20
# 1  ab2fadb5c7bbe55c80406d2b3692e969
# 2  246eac0ca4d02e73d8768a5acb9b89d7
# 3  fdc12d21a19b9c69b479a2b62cd6fa53
# 4  f9d166ab9038f2ea54dff7c639cc7cd2
#
#                                            image_url
# 0  https://images.gr-assets.com/books/1447303603m...
# 1  https://images.gr-assets.com/books/1447303603m...
# 2  https://images.gr-assets.com/books/1447303603m...
# 3  https://images.gr-assets.com/books/1447303603m...
# 4  https://images.gr-assets.com/books/1447303603m...

# %%
df_ready.isna().sum()
# Out:
# book_id      0
# title        0
# name         0
# rating       0
# user_id      0
# image_url    0
# dtype: int64

# %%
# Use pivot_table to create a user-item matrix
matrix = df_ready.pivot_table(index='title', columns='user_id', values='rating').fillna(0)
print(matrix.shape)
matrix.head()
# Out:
# (19102, 5372)
# user_id                                             0007f8dd09337afd986d765569cf0110  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             000883382802f2d95a3dd545bb953882  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             00268e2e7b05159626c6dfff078aa795  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             002a023d3de233b4bd3ec4fc3e9c581a  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             002eff40d3de8ff36174a48d26d93da7  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             004d5e96c8a318aeb006af50f8cc949c  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        3.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             006aa0d5b77127f14798411d4303af5c  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             007f9b5648832bc0aef9b53f992c2baf  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             008ffafc7ea81f88131f5a254a8cef89  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             009235f414f42cfd0f76282f6aefe6c1  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             ...  \
# title                                               ...
# "Why Are All The Black Kids Sitting Together in...  ...
# #GIRLBOSS                                           ...
# #Hater                                              ...
# #Nerd                                               ...
# #Player                                             ...
#
# user_id                                             ffc4bd4485bcd97a63cf40fdb9ce4f54  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             ffca1494ab9fd9c7fd3513e914e23141  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             ffd156f9a70275624951826b946b0c3e  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             ffd6c953994c599ce74e90874e3c7809  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             ffd6c966d94d3d06c8cc4480536082b4  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             ffd8f0635d15905b37ae3ab6743af80c  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             ffe776933441cd373201fa7fbd5dd321  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             ffed6b59d3554e94fccd5e831df8d19a  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             fff3a250fbc018ad2c2c2d45c86734da  \
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# user_id                                             ffff7cafdaf5196383cb2efca08fb6fe
# title
# "Why Are All The Black Kids Sitting Together in...                               0.0
# #GIRLBOSS                                                                        0.0
# #Hater                                                                           0.0
# #Nerd                                                                            0.0
# #Player                                                                          0.0
#
# [5 rows x 5372 columns]

# %% [markdown]
# # Recommender System: Collaborative Filtering

# %%
similarity_scores = cosine_similarity(matrix)

# %%
similarity_scores.shape
# Out:
# (19102, 19102)

# %%
def recommend(book_name):
    # fetch index of book
    index = np.where(matrix.index == book_name)[0][0]
    
    # Get similar books
    similar_books = sorted(list(enumerate(similarity_scores[index])), key=lambda x:x[1], reverse=True)[1:51]
    
    book_list = []
    for i in similar_books:
        book = []
        temp_df = df_ready[df_ready['title'] == matrix.index[i[0]]]
        book.extend(list(temp_df.drop_duplicates('title')['title'].values))
        book.extend(list(temp_df.drop_duplicates('title')['name'].values))
        book.extend(list(temp_df.drop_duplicates('title')['image_url'].values))
        book_list.append(book)
    
    return book_list

# %%
recommend("The Hobbit")
# Out:
# [['The Fellowship of the Ring',
#   'J.R.R. Tolkien',
#   'https://images.gr-assets.com/books/1298411339m/34.jpg'],
#  ['The Two Towers',
#   'J.R.R. Tolkien',
#   'https://images.gr-assets.com/books/1298415523m/15241.jpg'],
#  ['The Return of the King',
#   'J.R.R. Tolkien',
#   'https://images.gr-assets.com/books/1389977161m/18512.jpg'],
#  ["Harry Potter and the Sorcerer's Stone",
#   'J.K. Rowling',
#   'https://images.gr-assets.com/books/1474154022m/3.jpg'],
#  ['Harry Potter and the Order of the Phoenix',
#   'J.K. Rowling',
#   'https://images.gr-assets.com/books/1507396732m/2.jpg'],
#  ['The Hunger Games',
#   'Suzanne Collins',
#   'https://images.gr-assets.com/books/1447303603m/2767052.jpg'],
#  ['Catching Fire',
#   'Suzanne Collins',
#   'https://images.gr-assets.com/books/1358273780m/6148028.jpg'],
#  ['Harry Potter and the Deathly Hallows',
#   'J.K. Rowling',
#   'https://images.gr-assets.com/books/1474171184m/136251.jpg'],
#  ['Romeo and Juliet',
#   'William Shakespeare',
#   'https://images.gr-assets.com/books/1503315424m/18135.jpg'],
#  ['Harry Potter and the Prisoner of Azkaban',
#   'J.K. Rowling',
#   'https://images.gr-assets.com/books/1499277281m/5.jpg'],
#  ['A Game of Thrones',
#   'George R.R. Martin',
#   'https://images.gr-assets.com/books/1436732693m/13496.jpg'],
#  ['The Lion, the Witch, and the Wardrobe',
#   'C.S. Lewis',
#   'https://images.gr-assets.com/books/1353029077m/100915.jpg'],
#  ['Harry Potter and the Goblet of Fire',
#   'J.K. Rowling',
#   'https://images.gr-assets.com/books/1361482611m/6.jpg'],
#  ["Ender's Game",
#   'Orson Scott Card',
#   'https://images.gr-assets.com/books/1408303130m/375802.jpg'],
#  ['Mockingjay',
#   'Suzanne Collins',
#   'https://images.gr-assets.com/books/1358275419m/7260188.jpg'],
#  ['The Graveyard Book',
#   'Neil Gaiman',
#   'https://images.gr-assets.com/books/1303859949m/2213661.jpg'],
#  ['1984',
#   'George Orwell',
#   'https://images.gr-assets.com/books/1348990566m/5470.jpg'],
#  ['Harry Potter and the Half-Blood Prince',
#   'J.K. Rowling',
#   'https://images.gr-assets.com/books/1361039191m/1.jpg'],
#  ['Harry Potter and the Chamber of Secrets',
#   'J.K. Rowling',
#   'https://images.gr-assets.com/books/1474169725m/15881.jpg'],
#  ['To Kill a Mockingbird',
#   'Harper Lee',
#   'https://images.gr-assets.com/books/1361975680m/2657.jpg'],
#  ['The Great Gatsby',
#   'F. Scott Fitzgerald',
#   'https://images.gr-assets.com/books/1490528560m/4671.jpg'],
#  ['Brave New World',
#   'Aldous Huxley',
#   'https://images.gr-assets.com/books/1487389574m/5129.jpg'],
#  ['The Martian',
#   'Andy Weir',
#   'https://images.gr-assets.com/books/1413706054m/18007564.jpg'],
#  ['A Clash of Kings ',
#   'George R.R. Martin',
#   'https://images.gr-assets.com/books/1358254974m/10572.jpg'],
#  ['Animal Farm',
#   'George Orwell',
#   'https://images.gr-assets.com/books/1424037542m/7613.jpg'],
#  ['A Wrinkle in Time',
#   "Madeleine L'Engle",
#   'https://images.gr-assets.com/books/1329061522m/18131.jpg'],
#  ['The Giver',
#   'Lois Lowry',
#   'https://images.gr-assets.com/books/1342493368m/3636.jpg'],
#  ['Persuasion',
#   'Jane Austen',
#   'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'],
#  ['Pride and Prejudice',
#   'Jane Austen',
#   'https://images.gr-assets.com/books/1320399351m/1885.jpg'],
#  ['The Lightning Thief',
#   'Rick Riordan',
#   'https://images.gr-assets.com/books/1400602609m/28187.jpg'],
#  ['Dracula',
#   'Bram Stoker',
#   'https://images.gr-assets.com/books/1387151694m/17245.jpg'],
#  ['The Ocean at the End of the Lane',
#   'Neil Gaiman',
#   'https://images.gr-assets.com/books/1497098563m/15783514.jpg'],
#  ['A Christmas Carol',
#   'Charles Dickens',
#   'https://images.gr-assets.com/books/1406512317m/5326.jpg'],
#  ['Little Women',
#   'Louisa May Alcott',
#   'https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png'],
#  ['Lord of the Flies',
#   'William Golding',
#   'https://images.gr-assets.com/books/1327869409m/7624.jpg'],
#  ['The Book Thief',
#   'Markus Zusak',
#   'https://images.gr-assets.com/books/1390053681m/19063.jpg'],
#  ['The Voyage of the Dawn Treader',
#   'C.S. Lewis',
#   'https://images.gr-assets.com/books/1343185059m/140225.jpg'],
#  ['Of Mice and Men',
#   'John Steinbeck',
#   'https://images.gr-assets.com/books/1437235233m/890.jpg'],
#  ['The Scarlet Letter',
#   'Nathaniel Hawthorne',
#   'https://images.gr-assets.com/books/1404810944m/12296.jpg'],
#  ['Sense and Sensibility',
#   'Jane Austen',
#   'https://images.gr-assets.com/books/1397245675m/14935.jpg'],
#  ['Miss Peregrine’s Home for Peculiar Children',
#   'Ransom Riggs',
#   'https://images.gr-assets.com/books/1472782916m/9460487.jpg'],
#  ["The Hitchhiker's Guide to the Galaxy",
#   'Douglas Adams',
#   'https://images.gr-assets.com/books/1327656754m/11.jpg'],
#  ['A Feast for Crows',
#   'George R.R. Martin',
#   'https://images.gr-assets.com/books/1429538615m/13497.jpg'],
#  ['Hamlet',
#   'William Shakespeare',
#   'https://images.gr-assets.com/books/1351051208m/1420.jpg'],
#  ['The Golden Compass',
#   'Philip Pullman',
#   'https://images.gr-assets.com/books/1505766203m/119322.jpg'],
#  ['The Night Circus',
#   'Erin Morgenstern',
#   'https://images.gr-assets.com/books/1387124618m/9361589.jpg'],
#  ['The Help',
#   'Kathryn Stockett',
#   'https://images.gr-assets.com/books/1346100365m/4667024.jpg'],
#  ['Coraline',
#   'Neil Gaiman',
#   'https://images.gr-assets.com/books/1493497435m/17061.jpg'],
#  ['The Adventures of Huckleberry Finn',
#   'Mark Twain',
#   'https://images.gr-assets.com/books/1405973850m/2956.jpg'],
#  ['Jane Eyre',
#   'Charlotte Bronte',
#   'https://images.gr-assets.com/books/1327867269m/10210.jpg']]
